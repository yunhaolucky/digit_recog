# %% [markdown]
# ## Display digit

# %% [markdown]
# To get the general idea of the MNIST dataset, I random pick digits in dataset and display them.

# %%
run display_random_digit.py

# %% [markdown]
# We can notice that the most of the image are centered. But we still needs to deskew the data.

# %% [markdown]
# ## Baseline SVM

# %% [markdown]
# Before preprocessing the data, I run SVM with Gaussian kernel to get the baseline accuracy.
